# %% [markdown]
# # **Module 13: R for Data Science**

# %%
installed.packages() #This is the packages there are installed on our system
# Out:
#            Package    LibPath                       Version  Priority
# IRdisplay  IRdisplay  /usr/local/lib/R/site-library 0.7.0    NA
# IRkernel   IRkernel   /usr/local/lib/R/site-library 1.1.1    NA
# pbdZMQ     pbdZMQ     /usr/local/lib/R/site-library 0.3-3.1  NA
# repr       repr       /usr/local/lib/R/site-library 1.1.0    NA
# uuid       uuid       /usr/local/lib/R/site-library 0.1-4    NA
# askpass    askpass    /usr/lib/R/site-library       1.1      NA
# assertthat assertthat /usr/lib/R/site-library       0.2.1    NA
# backports  backports  /usr/lib/R/site-library       1.2.0    NA
# base64enc  base64enc  /usr/lib/R/site-library       0.1-3    NA
# BH         BH         /usr/lib/R/site-library       1.72.0-3 NA
# blob       blob       /usr/lib/R/site-library       1.2.1    NA
# brew       brew       /usr/lib/R/site-library       1.0-6    NA
# brio       brio       /usr/lib/R/site-library       1.1.0    NA
# broom      broom      /usr/lib/R/site-library       0.7.2    NA
# ...

# %%
install.packages("tidyverse") #A package specifically used for Data Science with many packages
#includes ggplot2, tibble, tidyr, readr, purrr, dplyr, stringr, forcats
#ggplot2 is a package for creating graphics and data visualizations
#tibble is a package for faster data processing with Data Frames
#tidyr is a package used to make data processing and transforming data easier
#readr is a package used to import dataframes
#purrr is a package used in creating functions, lists, map functions, and converted loops 
#dyplr is a more advanced Data Processing package than tidyr
#stringer is a package for making working with Strings significantly easier and faster
#forcats a specialized package used for categorical data (a very beneficial package to use as a preprocessing step before Supervised Learning)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %% [markdown]
# R cHEATSHEET
# https://www.tidyverse.org/packages/
# https://github.com/rstudio/cheatsheets/blob/master/data-import.pdf
# https://github.com/rstudio/cheatsheets/blob/master/purrr.pdf
# https://github.com/rstudio/cheatsheets/blob/master/data-transformation.pdf
# https://forcats.tidyverse.org/

# %%
library(tidyverse) #The command used to load a package, and it displays and refers to the place where the package is contained
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.4     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
1.2+2
#This is an example of Math in R
# Out:
# [1] 3.2

# %%
# Install the package named "XML".
#The xml2 package is the updated version of XML, making it easy to work with HTML and XML from R. The API is considered to be inspired by jQuery.

 install.packages("xml2")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(IRdisplay) #IRdisplay is a front-end package for Jupyter for display


  display_html("<iframe width='560' height='315' src='https://www.youtube.com/embed/_V8eKsto3Ug?rel=0&amp;controls=0&amp;showinfo=0'</iframe>")

  #How to import a Youtube Video Link in Project
# Out:
# <iframe width='560' height='315' src='https://www.youtube.com/embed/_V8eKsto3Ug?rel=0&amp;controls=0&amp;showinfo=0'</iframe>

# %%
#R uses <- is an assignment sign as compare to other programming languages which uses the eaqual sign(=) as an assignment
#<- is how to assign variables equivalent to "=" in Python
myString <- "Hello, World!"
print ( myString) #print prints the variable
# Out:
# [1] "Hello, World!"

# %%
# My first program in R Programming
myvariable <-"Hello, Anade!"
print (myvariable)
# Out:
# [1] "Hello, Anade!"

# %%
if(FALSE) {}

myString <- "Hello, World!"
print ( myString)
# Out:
# [1] "Hello, World!"

# %%
library(magrittr) #A package that utilizes pipe operators
#It takes the output of a previous function and passes it into another function as an argument (an eliminate mechanism). A sequence of data analysis in steps.
#considered one of the most important operator packages in R
library(dplyr) #dyplr is a more advanced Data Processing package than tidyr
# Out:
# Attaching package: ‘magrittr’
#
#
# The following object is masked from ‘package:purrr’:
#
#     set_names
#
#
# The following object is masked from ‘package:tidyr’:
#
#     extract

# %%
sex <- c("M", "F", "M", "F", "M", "F", "M", "F", "M", "F", "M", "F") #c represents column and combines our data sets together
stage <- c("I", "II", "II", "I", "II", "II", "I", "II", "II", "I", "II", "II")
treatment <- c("A", "A", "A", "A", "B", "B", "B", "B", "P", "P", "P", "P")
myc <- c(2343, 457, 4593, 9035, 3450, 3524, 958, 1053, 8674, 3424, 463, 5105)

# %%
sex
# Out:
#  [1] "M" "F" "M" "F" "M" "F" "M" "F" "M" "F" "M" "F"

# %%
stage
# Out:
#  [1] "I"  "II" "II" "I"  "II" "II" "I"  "II" "II" "I"  "II" "II"

# %%
treatment
# Out:
#  [1] "A" "A" "A" "A" "B" "B" "B" "B" "P" "P" "P" "P"

# %%
myc
# Out:
#  [1] 2343  457 4593 9035 3450 3524  958 1053 8674 3424  463 5105

# %%
#data.frame is the code to turn our data into an array or dataframe.
#This is where we designate here
meta <- data.frame(sex, stage, treatment, myc)

# %%
row.names(meta) <- paste("sample", 1:12, sep="2") #row.names named the rows in our table as Sample 1-12, with no space in-between Sample and number
#sep gives us the space between the rows and it gives ability to add a value

# %%
meta
# Out:
#           sex stage treatment myc
# sample21  M   I     A         2343
# sample22  F   II    A          457
# sample23  M   II    A         4593
# sample24  F   I     A         9035
# sample25  M   II    B         3450
# sample26  F   II    B         3524
# sample27  M   I     B          958
# sample28  F   II    B         1053
# sample29  M   II    P         8674
# sample210 F   I     P         3424
# sample211 M   II    P          463
# sample212 F   II    P         5105

# %%
row.names(meta) <- paste("sample", 1:12) #row.names named the rows in our table as Sample 1-12, with no space in-between Sample and number
#sep gives us the space between the rows and it gives ability to add a value

# %%
meta
# Out:
#           sex stage treatment myc
# sample 1  M   I     A         2343
# sample 2  F   II    A          457
# sample 3  M   II    A         4593
# sample 4  F   I     A         9035
# sample 5  M   II    B         3450
# sample 6  F   II    B         3524
# sample 7  M   I     B          958
# sample 8  F   II    B         1053
# sample 9  M   II    P         8674
# sample 10 F   I     P         3424
# sample 11 M   II    P          463
# sample 12 F   II    P         5105

# %%
row.names(meta) <- paste("sample", 1:12, sep="") #row.names named the rows in our table as Sample 1-12, with no space in-between Sample and number
#sep gives us the ability to change or add space between the rows and it gives ability to add a value before our values within the table

# %%
meta
# Out:
#          sex stage treatment myc
# sample1  M   I     A         2343
# sample2  F   II    A          457
# sample3  M   II    A         4593
# sample4  F   I     A         9035
# sample5  M   II    B         3450
# sample6  F   II    B         3524
# sample7  M   I     B          958
# sample8  F   II    B         1053
# sample9  M   II    P         8674
# sample10 F   I     P         3424
# sample11 M   II    P          463
# sample12 F   II    P         5105

# %% [markdown]
# Using the meta data frame from question #1, write out the R code you would use to perform the following operations (questions DO NOT build upon each other):
#
# return only the treatment and sex columns using []:
#
# return the treatment values for samples 5, 7, 9, and 10 using []:
#
# use filter() to return all data for those samples receiving treatment P:
#
# use filter()/select()to return only the stage and treatment columns for those samples with myc > 5000:
#
# remove the treatment column from the dataset using []:
#
# remove samples 7, 8 and 9 from the dataset using []:
#
# keep only samples 1-6 using []:
#
# add a column called pre_treatment to the beginning of the dataframe with the
#
# values T, F, F, F, T, T, F, T, F, F, T, T (Hint: use cbind()):
#
# change the names of the columns to: “A”, “B”, “C”, “D”:

# %%
meta[c(1,3)] #this differntiates the columns that we want returned
#R does not start from 0 in a dataframe, it stars from 1
# Out:
#          sex treatment
# sample1  M   A
# sample2  F   A
# sample3  M   A
# sample4  F   A
# sample5  M   B
# sample6  F   B
# sample7  M   B
# sample8  F   B
# sample9  M   P
# sample10 F   P
# sample11 M   P
# sample12 F   P

# %%
#The first numbers represent the row and the last number after parenthisis is column name
meta[c(5,7,9,10), 3]
#c(row), column]
# Out:
# [1] "B" "B" "P" "P"

# %%
filter(meta, treatment == "P") #finds specifc values within our dataset
#meta is the name of our dataframe and treatment is our column name and p returns all of the values equal to "P"
# Out:
#          sex stage treatment myc
# sample9  M   II    P         8674
# sample10 F   I     P         3424
# sample11 M   II    P          463
# sample12 F   II    P         5105

# %%
filter(meta, treatment != "P") #finds specifc values within our dataset
#meta is the name of our dataframe and treatment is our column name and p returns all of the values that do not equal "P"
# Out:
#         sex stage treatment myc
# sample1 M   I     A         2343
# sample2 F   II    A          457
# sample3 M   II    A         4593
# sample4 F   I     A         9035
# sample5 M   II    B         3450
# sample6 F   II    B         3524
# sample7 M   I     B          958
# sample8 F   II    B         1053

# %% [markdown]
# use filter()/select()to return only the stage and treatment columns for those samples with myc > 5000:

# %%
#use filter()/select()to return only the stage and treatment columns for those samples with myc > 5000:
filter(meta, myc > 5000) %>% select(stage, treatment) #%>% used as a Pipe and carries over to the next functions for faster processing
#We take meta dataframe and look to pull out the samples over 5000 only in the stage and treatment column
# Out:
#          stage treatment
# sample4  I     A
# sample9  II    P
# sample12 II    P

# %%
filter(meta, sex > 5000) #chr (character) means string, dbl stands for double class (integers and floats)
# Out:
#          sex stage treatment myc
# sample1  M   I     A         2343
# sample2  F   II    A          457
# sample3  M   II    A         4593
# sample4  F   I     A         9035
# sample5  M   II    B         3450
# sample6  F   II    B         3524
# sample7  M   I     B          958
# sample8  F   II    B         1053
# sample9  M   II    P         8674
# sample10 F   I     P         3424
# sample11 M   II    P          463
# sample12 F   II    P         5105

# %%
#removes the treatment column from the dataset using []:
#-3 siginifies remove the third column
meta[, -3]
# Out:
#          sex stage myc
# sample1  M   I     2343
# sample2  F   II     457
# sample3  M   II    4593
# sample4  F   I     9035
# sample5  M   II    3450
# sample6  F   II    3524
# sample7  M   I      958
# sample8  F   II    1053
# sample9  M   II    8674
# sample10 F   I     3424
# sample11 M   II     463
# sample12 F   II    5105

# %%
meta[, -2] #same thing happens when we replace it with -2 it removes second column
# Out:
#          sex treatment myc
# sample1  M   A         2343
# sample2  F   A          457
# sample3  M   A         4593
# sample4  F   A         9035
# sample5  M   B         3450
# sample6  F   B         3524
# sample7  M   B          958
# sample8  F   B         1053
# sample9  M   P         8674
# sample10 F   P         3424
# sample11 M   P          463
# sample12 F   P         5105

# %%
#remove samples 7, 8 and 9 from the dataset using []:
meta[-7:-9, ]
# Out:
#          sex stage treatment myc
# sample1  M   I     A         2343
# sample2  F   II    A          457
# sample3  M   II    A         4593
# sample4  F   I     A         9035
# sample5  M   II    B         3450
# sample6  F   II    B         3524
# sample10 F   I     P         3424
# sample11 M   II    P          463
# sample12 F   II    P         5105

# %%
meta [-1:-6, ]
# Out:
#          sex stage treatment myc
# sample7  M   I     B          958
# sample8  F   II    B         1053
# sample9  M   II    P         8674
# sample10 F   I     P         3424
# sample11 M   II    P          463
# sample12 F   II    P         5105

# %%
meta [-1] #removes column
# Out:
#          stage treatment myc
# sample1  I     A         2343
# sample2  II    A          457
# sample3  II    A         4593
# sample4  I     A         9035
# sample5  II    B         3450
# sample6  II    B         3524
# sample7  I     B          958
# sample8  II    B         1053
# sample9  II    P         8674
# sample10 I     P         3424
# sample11 II    P          463
# sample12 II    P         5105

# %%
meta [1:6, ] #grab first 6 samples from data frame
# Out:
#         sex stage treatment myc
# sample1 M   I     A         2343
# sample2 F   II    A          457
# sample3 M   II    A         4593
# sample4 F   I     A         9035
# sample5 M   II    B         3450
# sample6 F   II    B         3524

# %%
pre_treatment <- c(T, F, F, F, T, T, F, T, F, F, T, T)

# %%
cbind(pre_treatment, meta) #cbind adds our new data values into a column 
#lgl stands for logical (True and False are considered logical vectors/operators in R)
# Out:
#          pre_treatment sex stage treatment myc
# sample1   TRUE         M   I     A         2343
# sample2  FALSE         F   II    A          457
# sample3  FALSE         M   II    A         4593
# sample4  FALSE         F   I     A         9035
# sample5   TRUE         M   II    B         3450
# sample6   TRUE         F   II    B         3524
# sample7  FALSE         M   I     B          958
# sample8   TRUE         F   II    B         1053
# sample9  FALSE         M   II    P         8674
# sample10 FALSE         F   I     P         3424
# sample11  TRUE         M   II    P          463
# sample12  TRUE         F   II    P         5105

# %% [markdown]
# https://cran.r-project.org/web/packages/hablar/vignettes/convert.html

# %%
colnames(meta) <- c("A", "B", "C", "D") #column names is the code we use to name columns
meta[]
# Out:
#          A B  C D
# sample1  M I  A 2343
# sample2  F II A  457
# sample3  M II A 4593
# sample4  F I  A 9035
# sample5  M II B 3450
# sample6  F II B 3524
# sample7  M I  B  958
# sample8  F II B 1053
# sample9  M II P 8674
# sample10 F I  P 3424
# sample11 M II P  463
# sample12 F II P 5105

# %% [markdown]
# https://r4ds.had.co.nz/introduction.html

# %% [markdown]
# # **Module 14: R - Tibbles and ggplot**

# %%
library(ggplot2)
library(readr)

# %%
data <- read_csv("https://raw.githubusercontent.com/Worlddatascience/techtalentsouth/e9f571dc21b881addc15aeea49954fc009f74958/datascience/r/14_mod_r_tibbles_ggplot/dataSets/EconomistData.csv")
# Out:
# ── Column specification ────────────────────────────────────────────────────────
# cols(
#   Country = col_character(),
#   HDI.Rank = col_double(),
#   HDI = col_double(),
#   CPI = col_double(),
#   Region = col_character()
# )

# %%
data$Region <- factor(data$Region,
                     levels = c("EU W. Europe",
                                "Americas",
                                "Asia Pacific",
                                "East EU Cemt Asia",
                                "MENA",
                                "SSA"),
                     labels = c("OECD",
                                "Americas",
                                "Asia &\nOceania",
                                "Central &\nEastern Europe",
                                "Middle East &\nnorth Africa",
                                "Sub-Saharan\nAfrica"))

# %%
# Create a scatter plot with CPI on the x axis and HDI on the y axis.
ggplot(data, aes(x = CPI, y = HDI)) + geom_point()
# Out:
# plot without title

# %%
#Color the points blue
ggplot(data, aes(x = CPI, y = HDI)) + geom_point(color = "blue")
# Out:
# plot without title

# %%
#Map the color of the the points to Region
ggplot(data, aes(x = CPI, y = HDI)) + geom_point(aes(color = Region))
# Out:
# plot without title

# %%
# Make the points bigger by setting size to 2
ggplot(data, aes(x = CPI, y = HDI)) + geom_point(aes(color = Region), size = 2)
# Out:
# plot without title

# %%
# Map the size of the points to HDI.Rank
ggplot(data, aes(x = CPI, y = HDI)) + geom_point(aes(color = Region, size =  HDI.Rank))
# Out:
# plot without title

# %%
#A. Re-create a scatter plot with CPI on the x axis and HDI on the y axis (as you did in the previous exercise).
ggplot(data, aes(x = CPI, y = HDI)) + geom_point()
# Out:
# plot without title

# %%
#B. Overlay a smoothing line on top of the scatter plot using geom_smooth.
ggplot(data, aes(x = CPI, y = HDI)) + geom_point() + geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
# Overlay a smoothing line on top of the scatter plot using geom_smooth, 
# but use a linear model for the predictions. Hint: see stat_smooth.
ggplot(data, aes(x = CPI, y = HDI)) + geom_point() + geom_smooth(method = "lm")
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %%
# Overlay a smoothing line on top of the scatter plot using geom_line. 
# Hint: change the statistical transformation
ggplot(data, aes(x = CPI, y = HDI)) + geom_point() + geom_line(stat = "smooth", method = "loess")
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %%
# **BONUS**: Overlay a smoothing line on top of the scatter plot using the
# default loess method, but make it less smooth. Hint: see ?loess
ggplot(data, aes(x = CPI, y = HDI)) + geom_point() + geom_smooth(span = .4)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %% [markdown]
# Exercise 3

# %%
# Create a scatter plot with CPI on the x axis and HDI on the y axis. Color the points to indicate region
ggplot(data, aes(x = CPI, y = HDI, color = "Region")) + geom_point()
# Out:
# plot without title

# %%
# Modify the x, y, and color scales so that they have more easily-understood names 
# (e.g., spell out “Human development Index” instead of “HDI”).
ggplot(data, aes(x = CPI, y = HDI, color = "Region")) + geom_point() +
scale_x_continuous(name = "Corruption Perception Index") +
scale_y_continuous(name = "Human Development Index") +
scale_color_discrete(name = "Region of the world")
# Out:
# plot without title

# %%
#Modify the color scale to use specific values of your choosing. Hint: see scale_color_manual.
ggplot(data, aes(x = CPI, y = HDI, color = "Region")) +
geom_point() +
scale_x_continuous(name = "Corruption Perception Index") +
scale_y_continuous(name = "Human Development Index") +
  scale_color_manual(name = "Region of the world",
                     values = c("#24576D",
                                "#099DD7",
                                "#28AADC",
                                "#248E84",
                                "#F2583F",
                                "#96503F"))
# Out:
# plot without title

# %% [markdown]
# #**Module 15: Data Transformation with R**

# %%
library(tidyverse)
library(readxl)

# %% [markdown]
# Exercise 1

# %%
list.files(readr_example(""))
# Out:
# [1] "challenge.csv"     "epa78.txt"         "example.log"
# [4] "fwf-sample.txt"    "massey-rating.txt" "mtcars.csv"
# [7] "mtcars.csv.bz2"    "mtcars.csv.zip"

# %% [markdown]
# Exercise 2

# %%
data1 = read_csv(readr_example('mtcars.csv'))
data1
# Out:
# ── Column specification ────────────────────────────────────────────────────────
# cols(
#   mpg = col_double(),
#   cyl = col_double(),
#   disp = col_double(),
#   hp = col_double(),
#   drat = col_double(),
#   wt = col_double(),
#   qsec = col_double(),
#   vs = col_double(),
#   am = col_double(),
#   gear = col_double(),
#   carb = col_double()
# )
#    mpg  cyl disp  hp  drat wt    qsec  vs am gear carb
# 1  21.0 6   160.0 110 3.90 2.620 16.46 0  1  4    4
# 2  21.0 6   160.0 110 3.90 2.875 17.02 0  1  4    4
# 3  22.8 4   108.0  93 3.85 2.320 18.61 1  1  4    1
# 4  21.4 6   258.0 110 3.08 3.215 19.44 1  0  3    1
# 5  18.7 8   360.0 175 3.15 3.440 17.02 0  0  3    2
# 6  18.1 6   225.0 105 2.76 3.460 20.22 1  0  3    1
# 7  14.3 8   360.0 245 3.21 3.570 15.84 0  0  3    4
# 8  24.4 4   146.7  62 3.69 3.190 20.00 1  0  4    2
# 9  22.8 4   140.8  95 3.92 3.150 22.90 1  0  4    2
# 10 19.2 6   167.6 123 3.92 3.440 18.30 1  0  4    4
# ...

# %% [markdown]
# Exercise 3

# %%
head(data1,10)
# Out:
#    mpg  cyl disp  hp  drat wt    qsec  vs am gear carb
# 1  21.0 6   160.0 110 3.90 2.620 16.46 0  1  4    4
# 2  21.0 6   160.0 110 3.90 2.875 17.02 0  1  4    4
# 3  22.8 4   108.0  93 3.85 2.320 18.61 1  1  4    1
# 4  21.4 6   258.0 110 3.08 3.215 19.44 1  0  3    1
# 5  18.7 8   360.0 175 3.15 3.440 17.02 0  0  3    2
# 6  18.1 6   225.0 105 2.76 3.460 20.22 1  0  3    1
# 7  14.3 8   360.0 245 3.21 3.570 15.84 0  0  3    4
# 8  24.4 4   146.7  62 3.69 3.190 20.00 1  0  4    2
# 9  22.8 4   140.8  95 3.92 3.150 22.90 1  0  4    2
# 10 19.2 6   167.6 123 3.92 3.440 18.30 1  0  4    4

# %% [markdown]
# Exercise 4

# %%
read_log(readr_example("example.log"))
# Out:
# ── Column specification ────────────────────────────────────────────────────────
# cols(
#   X1 = col_character(),
#   X2 = col_logical(),
#   X3 = col_character(),
#   X4 = col_character(),
#   X5 = col_character(),
#   X6 = col_double(),
#   X7 = col_double()
# )
#   X1           X2 X3                 X4
# 1 172.21.13.45 NA Microsoft\\JohnDoe 08/Apr/2001:17:39:04 -0800
# 2 127.0.0.1    NA frank              10/Oct/2000:13:55:36 -0700
#   X5                                               X6  X7
# 1 GET /scripts/iisadmin/ism.dll?http/serv HTTP/1.0 200 3401
# 2 GET /apache_pb.gif HTTP/1.0                      200 2326

# %% [markdown]
# Exercise 5

# %%
excel_sheets(readxl_example("datasets.xlsx"))
# Out:
# [1] "iris"     "mtcars"   "chickwts" "quakes"

# %% [markdown]
# Exercise 6

# %%
read_excel(readxl_example("datasets.xlsx"), sheet = 'quakes')
# Out:
#      lat    long   depth mag stations
# 1    -20.42 181.62 562   4.8 41
# 2    -20.62 181.03 650   4.2 15
# 3    -26.00 184.10  42   5.4 43
# 4    -17.97 181.66 626   4.1 19
# 5    -20.42 181.96 649   4.0 11
# 6    -19.68 184.31 195   4.0 12
# 7    -11.70 166.10  82   4.8 43
# 8    -28.11 181.93 194   4.4 15
# 9    -28.74 181.74 211   4.7 35
# 10   -17.47 179.59 622   4.3 19
# 11   -21.44 180.69 583   4.4 13
# 12   -12.26 167.00 249   4.6 16
# 13   -18.54 182.11 554   4.4 19
# 14   -21.00 181.66 600   4.4 10
# 15   -20.70 169.92 139   6.1 94
# 16   -15.94 184.95 306   4.3 11
# 17   -13.64 165.96  50   6.0 83
# 18   -17.83 181.50 590   4.5 21
# 19   -23.50 179.78 570   4.4 13
# 20   -22.63 180.31 598   4.4 18
# 21   -20.84 181.16 576   4.5 17
# 22   -10.98 166.32 211   4.2 12
# 23   -23.30 180.16 512   4.4 18
# 24   -30.20 182.00 125   4.7 22
# 25   -19.66 180.28 431   5.4 57
# 26   -17.94 181.49 537   4.0 15
# 27   -14.72 167.51 155   4.6 18
# 28   -16.46 180.79 498   5.2 79
# ...

# %% [markdown]
# Exercise 7

# %%
library(dplyr)

# %%
install.packages("AER", dependencies=TRUE)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# ...

# %%
install.packages("rdd", dependencies=TRUE)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(AER)
# Out:
# Loading required package: car
#
# Loading required package: carData
#
#
# Attaching package: ‘car’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     recode
#
#
# The following object is masked from ‘package:purrr’:
#
#     some
#
#
# Loading required package: lmtest
#
# Loading required package: zoo
#
#
# Attaching package: ‘zoo’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
#
# Loading required package: sandwich
#
# Loading required package: survival

# %%
data(Fertility, package="AER")
f1 <- Fertility
glimpse(f1)
# Out:
# Rows: 254,654
# Columns: 8
# $ morekids <fct> no, no, no, no, no, no, no, no, no, no, yes, no, no, no, no,…
# $ gender1  <fct> male, female, male, male, female, male, female, male, female…
# $ gender2  <fct> female, male, female, female, female, female, male, male, ma…
# $ age      <int> 27, 30, 27, 35, 30, 26, 29, 33, 29, 27, 28, 28, 35, 34, 32, …
# $ afam     <fct> no, no, no, yes, no, no, no, no, no, no, no, no, no, no, no,…
# $ hispanic <fct> no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, …
# $ other    <fct> no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, …
# $ work     <int> 0, 30, 0, 0, 22, 40, 0, 52, 0, 0, 0, 52, 52, 52, 8, 7, 0, 40…

# %% [markdown]
# Exercise 8

# %%
f1[35:50,c(4,8)]
# Out:
#    age work
# 35 28  20
# 36 33  12
# 37 32   0
# 38 26  52
# 39 32  52
# 40 28   0
# 41 32  40
# 42 35   0
# 43 33   0
# 44 32  42
# 45 29   0
# 46 29  52
# 47 31   0
# 48 30  51
# 49 28   0
# 50 29   0

# %% [markdown]
# Exercise 9

# %%
tail(f1, 1)
# Out:
#        morekids gender1 gender2 age afam hispanic other work
# 254654 yes      female  female  35  no   no       no    0

# %% [markdown]
# Exercise 10

# %%
count(f1, morekids == "yes")[2,2]
# Out:
# [1] 96912

# %% [markdown]
# Exercise 11

# %%
print("Male, male:")
count(f1, gender1 == "male" & gender2 == "male")[2,2]
print("Male, female:")
count(f1, gender1 == "male" & gender2 == "female")[2,2]
print("Female, male:")
count(f1, gender1 == "female" & gender2 == "male")[2,2]
print("Female, female:")
count(f1, gender1 == "female" & gender2 == "female")[2,2]
# Out:
# [1] "Male, male:"
# [1] 67799
# [1] "Male, female:"
# [1] 63185
# [1] "Female, male:"
# [1] 62724
# [1] "Female, female:"
# [1] 60946

# %% [markdown]
# # **Module 16: Exploratory Data Analysis**

# %%
library(modelr)

# %%
heights
# Out:
#      income height weight age marital   sex    education afqt
# 1     19000 60     155    53  married   female 13         6.841
# 2     35000 70     156    51  married   female 10        49.444
# 3    105000 65     195    52  married   male   16        99.393
# 4     40000 63     197    54  married   female 14        44.022
# 5     75000 66     190    49  married   male   14        59.683
# 6    102000 68     200    49  divorced  female 18        98.798
# 7         0 74     225    48  married   male   16        82.260
# 8     70000 64     160    54  divorced  female 12        50.283
# 9     60000 69     162    55  divorced  male   12        89.669
# 10   150000 69     194    54  divorced  male   13        95.977
# 11   115000 64     145    53  married   female 16        67.021
# 12   343830 62     170    51  married   female 16        88.416
# 13    40000 64     145    49  divorced  female 16        89.167
# 14    35000 66     128    52  married   female 14        51.390
# ...

# %%
?modelr

# %%
set.seed(1453)
N <- 100 ## no. of observations
weight <- runif(n=N, min=60, max=100) ## hypothetical weights in kg
height <- 2.2*weight + rnorm(n=N, mean=0, sd=10) ## hypothetical heights in cm
plot(weight, height, pch=19, xlab='Weight (kg)', ylab='Height (cm)', col='grey')

## Linear model fit
fit <- lm(height ~ weight)

## Plot model fit
plot(weight, height, pch=19, xlab='Weight (kg)', ylab='Height (cm)', col='grey')
lines(weight, predict(fit), col='black', lwd=3)
# Out:
# plot without title

# %% [markdown]
# exercise 3

# %%
fit2 <- na.omit(fit) # Method 1 - Remove NA

# %%
fit2
# Out:
# Call:
# lm(formula = height ~ weight)
#
# Coefficients:
# (Intercept)       weight
#       2.352        2.174

# %%
## Plot model fit
plot(weight, height, pch=19, xlab='Weight (kg)', ylab='Height (cm)', col='grey')
lines(weight, predict(fit2), col='black', lwd=3)
# Out:
# plot without title

# %% [markdown]
# Exercise 4

# %%
sqrt(mean((data$actual - data$predicted)^2))
# Out:
# Warning message:
# “Unknown or uninitialised column: `actual`.”
# Warning message:
# “Unknown or uninitialised column: `predicted`.”
# [1] NaN
